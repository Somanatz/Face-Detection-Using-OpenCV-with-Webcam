# %% [markdown]
# # Project 2. Real-time face detection- Cyber Security
#
# - **Problem Statement:** Build an application to detect face using opencv (Dataset not required / using webcam)

# %% [markdown]
# ### Installing OpenCV

# %% [markdown]
# # Step 1: Detecting Face from Image

# %%
pip install opencv-python
# Out:
# ...
#
# ...

# %% [markdown]
# ### Import the OpenCV Package

# %%
import cv2

imagePath = 'C:\\Users\\onsre\\Machine learning\\human.jpg'

# %% [markdown]
# ### Read the Image

# %%
img = cv2.imread(imagePath)

# %% [markdown]
# Let’s print the dimensions of this array:

# %%
img.shape
# Out:
# (183, 275, 3)

# %% [markdown]
# ### Convert the Image to Grayscale

# %%
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %% [markdown]
# the dimensions of this grayscale image:

# %%
gray_image.shape
# Out:
# (183, 275)

# %% [markdown]
# ### Load the Classifier

# %%
face_classifier = cv2.CascadeClassifier(
    cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
)

# %% [markdown]
# ### Perform the Face Detection

# %%
face = face_classifier.detectMultiScale(
    gray_image, scaleFactor=1.1, minNeighbors=5, minSize=(40, 40)
)

# %% [markdown]
# ### Drawing a Bounding Box

# %%
for (x, y, w, h) in face:
    cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 4)

# %% [markdown]
# ### Displaying the Image

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
import matplotlib.pyplot as plt



plt.figure(figsize=(20,10))
plt.imshow(img_rgb)
plt.axis('off')
# Out:
# (-0.5, 274.5, 182.5, -0.5)

# %% [markdown]
# # Step 2: Access the Webcam to Detect Live Face

# %%
video_capture = cv2.VideoCapture(0)

# %% [markdown]
# ### Identifying Faces in the Video Stream

# %%
def detect_bounding_box(vid):
    gray_image = cv2.cvtColor(vid, cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray_image, 1.1, 5, minSize=(40, 40))
    for (x, y, w, h) in faces:
        cv2.rectangle(vid, (x, y), (x + w, y + h), (0, 255, 0), 4)
    return faces

# %% [markdown]
# ### Creating a Loop for Real-Time Face Detection

# %%
while True:

    result, video_frame = video_capture.read()  # read frames from the video
    if result is False:
        break  # terminate the loop if the frame is not read successfully

    faces = detect_bounding_box(
        video_frame
    )  # apply the function we created to the video frame

    cv2.imshow(
        "My Face Detection Project", video_frame
    )  # display the processed frame in a window named "My Face Detection Project"

    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

video_capture.release()
cv2.destroyAllWindows()

# %% [markdown]
# # Conclusion:
#
# In this project, we successfully built an application for real-time face detection using OpenCV, a popular library for computer vision tasks. Our objective was to create a system capable of detecting human faces in real-time using the webcam, which has various applications in cybersecurity and surveillance.
#
# **Here's a summary of our key findings and achievements:**
#
# **Problem Statement:**
#
# The problem statement involved building an application to detect faces in real-time using OpenCV without the need for a specific dataset, instead utilizing the webcam feed as input.
# Implementation:
#
# - We utilized the Haar Cascade Classifier, a pre-trained model available in OpenCV, for face detection. This model works by analyzing features of the face, such as edges, and classifying regions of the image as faces based on these features.
#
# - We implemented the face detection algorithm in Python using OpenCV's functions and methods.
#
# - The application captures frames from the webcam in real-time, converts them to grayscale for better processing efficiency, and then applies the face detection algorithm to detect faces in each frame.
#
# - Detected faces are highlighted with rectangles drawn around them, providing a visual indication of the face detection process.
#
# - The application continuously displays the webcam feed with the detected faces in a window, allowing real-time monitoring of face detection.
